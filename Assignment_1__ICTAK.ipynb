# %% [markdown]
# # **ASSIGNMENT**
# **DATASET : IRIS**
#
# ---
#
#
#
# ---

# %% [markdown]
# **1. Read the dataset to python environment.**

# %%
# reading the Iris dataset into Python environment using the pandas library and the following command:

import pandas as pd #importin pandas library
iris_df = pd.read_excel(r"/content/drive/MyDrive/iris.xls")

# %%
# displaying the data

iris_df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# **2. Display the columns in the dataset**

# %%
# displaying the columns in the dataset using the following code

print(iris_df.columns)  #This will print the names of all the columns in the dataset.
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# So, from the above result, its visible that the given dataset includes 5 columns namely:
#
# .......................
#
# SL
#
# SW
#
# PL
#
# PW
#
# Classification
#
# ........................

# %% [markdown]
# **3. Calculate the mean of each column of the dataset**

# %%
# checking the datatype of each column

iris_df.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %% [markdown]
# So, SL, SW, PL and PW are numeric compared to Classification, which is object ie., string.

# %%
# calculating the mean of each column of the dataset using the following command:

print(iris_df.mean()) #This will print the mean value of each column in the dataset.
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
# <ipython-input-5-2def3c17ddce>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(iris_df.mean()) #This will print the mean value of each column in the dataset.

# %% [markdown]
# As mentioned above, mean can be calculated only for numeric values. so checking the mean of only numeric columns.

# %%
# Calculate mean of each column using numeric_only parameter

mean_values = iris_df.mean(numeric_only=True)

print(mean_values)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# **4. Check for the null values present in the dataset.**

# %%
#To check for null values in the dataset, using the following command:

print(iris_df.isnull().sum())  #This will print the number of null values present in each column of the dataset.

#If there are no null values in the dataset, the output of this code will show all zeros indicating that there are no null values in any of the columns. 
#If there are null values present in the dataset, the output will show the number of null values in each column.
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# The output means that there are no null values in the dataset provided, it means that every cell in the dataset contains a value and there are no missing or undefined values.

# %% [markdown]
# **5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.**

# %% [markdown]
# To perform meaningful visualizations using the Iris dataset, using various plotting libraries in Python like pandas, seaborn, and matplotlib.

# %%
# importing necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Bar plot using Pandas:**

# %%
import pandas as pd
import matplotlib.pyplot as plt #importing pyplot from matplotlib as plt

iris_df['Classification'].value_counts().plot(kind='bar')
plt.title('Count of Classification')
plt.xlabel('Classification')
plt.ylabel('Count')
plt.show()

#This will create a bar plot showing the count of each Classification in the Iris dataset.

# %% [markdown]
# **Box plot using seaborn:**

# %%
import seaborn as sns #importing seaborn 

sns.boxplot(data=iris_df, x='Classification', y='SL')
plt.title('Distribution of Sepal Length (SL) by Classification')
plt.xlabel('Classification')
plt.ylabel('SL')
plt.show()

#This will create a box plot showing the distribution of sepal length (SL) for each Classification in the Iris dataset.

# %% [markdown]
# **Histogram using matplotlib:**

# %%
import matplotlib.pyplot as plt

plt.hist(iris_df['PW'], bins=10, color='violet')
plt.title('Distribution of Petal Width (PW)')
plt.xlabel('PW')
plt.ylabel('Count')
plt.show()

#This will create a histogram showing the distribution of PW (Petal Width) in the Iris dataset.

# %% [markdown]
# **Scatter matrix plot using pandas**

# %%
# scatter matrix plot for all columns
pd.plotting.scatter_matrix(iris_df, diagonal='kde', alpha=0.8, c='r')
plt.suptitle("Scatter Matrix Plot for Iris Dataset")
plt.show()

# %% [markdown]
# **Scatter plot using matplotlib**

# %%
#scatter plot for Sepal Length (SL) vs Sepal Width (SW)


import matplotlib.pyplot as plt

# Create a dictionary to map the category names to colors
colors = {"Iris-setosa": "red", "Iris-versicolor": "green", "Iris-virginica": "blue"}

# Create the scatter plot with different colors for each category
plt.scatter(iris_df["SL"], iris_df["SW"], c=iris_df["Classification"].apply(lambda x: colors[x]))

# Add labels and title
plt.xlabel("SL")
plt.ylabel("SW")
plt.title("Scatter plot for Sepal Length (SL) vs Sepal Width (SW)")

# Add legend
for category, color in colors.items():
    plt.scatter([], [], c=color, label=category) # Dummy scatter plot to add legend
plt.legend()

plt.show()

 #color_map dictionary maps each flower species to a specific color. 
 #Then the apply function is used to apply this mapping to the "Classification" column of the dataset, so that each flower species is plotted with the corresponding color.

# %% [markdown]
# **Violin plot using seaborn**

# %%
# Create violin plot for Petal Length (PL)

sns.violinplot(x="PL", data=iris_df, color='brown')
plt.title("Violin plot for Petal Length (PL)")
plt.show()

# %% [markdown]
# **Pairplot using seaborn**

# %%
# Create pairplot for all columns

sns.pairplot(data=iris_df)
plt.suptitle("PAIRPLOT FOR IRIS DATASET", y=1.05, fontsize=16)
plt.show()

#  using the suptitle function from matplotlib to add the title at the top of the plot. 
# The y parameter adjusts the vertical position of the title, and the fontsize parameter sets the font size.

# %% [markdown]
# ---
#
#
#
# ---
